# %% [markdown]
# 訓練済みモデルを用いてChat Botを実行するNotebookです。
# Chat botは"Telegram"というサービスのAPIを使っています。

# %%
# !pip install python-telegram-bot
# Out:
# ...
#      |████████████████████████████████| 450kB 11.0MB/s
# ...
#      |████████████████████████████████| 61kB 7.0MB/s
# ...

# %%
# %cd /content/drive/MyDrive/RL_spring_final_project/
# Out:
# /content/drive/MyDrive/RL_spring_final_project

# %%
# !nvidia-smi
# Out:
# Tue Mar 23 13:16:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# 次のセルを実行することで、telegramアプリ内でbotと会話できるようになる。

# %%
# !python3 run_bot.py --model ./saves/reinforce_romance2/epoch_25_0.23437_0.16294.dat
# Out:
# 2021-03-23 13:30:45,269 INFO Bot is running
# 2021-03-23 13:30:45,269 INFO Scheduler started
# 2021-03-23 13:41:32,259 INFO Received signal 2 (SIGINT), stopping...
# 2021-03-23 13:41:32,259 INFO Scheduler has been shut down
# 2021-03-23 13:41:32,260 INFO Received signal 2 (SIGINT), stopping...
